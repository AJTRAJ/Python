# %%
# Using Arithmetic expressions
((10 + 2) * 100 / 5 - 200)
# Out:
# 40.0

# %%
# Using functions in an expression
pow(2, 10)
# Out:
# 1024

# %%
# Using eval in an expression
eval( "2.5+2.5" )
# Out:
# 5.0

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-a26645e8cd06> in <module>
# ----> 1 dhhfj
#
# NameError: name 'dhhfj' is not defined
